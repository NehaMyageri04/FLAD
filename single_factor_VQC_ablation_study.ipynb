# %% [markdown]
# <a href="https://colab.research.google.com/github/NehaMyageri04/FLAD/blob/main/single_factor_VQC_ablation_study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/NehaMyageri04/FLAD.git
# Out:
# Cloning into 'FLAD'...
# remote: Enumerating objects: 318, done.
# remote: Counting objects: 100% (115/115), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 318 (delta 65), reused 51 (delta 30), pack-reused 203 (from 1)
# Receiving objects: 100% (318/318), 13.75 MiB | 35.38 MiB/s, done.
# Resolving deltas: 100% (154/154), done.

# %%
# %cd FLAD
# Out:
# /content/FLAD/FLAD

# %%
# !pwd
# !ls
# Out:
# /content/FLAD/FLAD
#  1.FLAD
#  2.FLTrust
#  3.Others_Defences
#  4.FLAME
#  5.PFLAD
#  6.QBAD-FL
#  data
#  Final_Execution_of_QBAD_non_iid_and_iid_and_scalability.ipynb
# 'IID_&_NON-IID_10_rounds.ipynb'
#  Initial_set_and_execution.ipynb
#  README.md
#  VQC_circuit_on_case_5_MPAF_attack.ipynb
#  VQC_circuit_on_case_5_MPAF_attack_metrics.ipynb

# %%
# !pip install pennylane
# !pip install scikit-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 59.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 937.5/937.5 kB 46.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.5/25.5 MB 48.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 65.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.2/167.2 kB 16.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 82.3 MB/s eta 0:00:00
# ...

# %%
# %cd /content/FLAD
# !pwd
# !ls
# Out:
# /content/FLAD
# /content/FLAD
#  1.FLAD
#  2.FLTrust
#  3.Others_Defences
#  4.FLAME
#  5.PFLAD
#  6.QBAD-FL
#  data
#  Final_Execution_of_QBAD_non_iid_and_iid_and_scalability.ipynb
#  FLAD
# 'IID_&_NON-IID_10_rounds.ipynb'
#  Initial_set_and_execution.ipynb
#  README.md
#  VQC_circuit_on_case_5_MPAF_attack.ipynb
#  VQC_circuit_on_case_5_MPAF_attack_metrics.ipynb

# %%
# !find /content/FLAD -name "test_qbad_fl.py"
# Out:
# /content/FLAD/6.QBAD-FL/test_qbad_fl.py
# /content/FLAD/FLAD/6.QBAD-FL/test_qbad_fl.py

# %%
# %cd /content/FLAD/6.QBAD-FL
# Out:
# /content/FLAD/6.QBAD-FL

# %%
# !ls
# Out:
# Attack.py		   main.py		  run_full_experiment.py
# benchmark_qbad_vs_flad.py  metrics.py		  TESTING_GUIDE.md
# checkpoints		   Models.py		  test_qbad_fl.py
# clients.py		   README.md		  VQC_ARCHITECTURE.md
# config.yaml		   requirements_test.txt  vqc_circuit.py
# getData.py		   results

# %%
# !cp Models.py Models_ablation.py
# !cp test_qbad_fl.py test_qbad_fl_ablation.py

# %%
# !ls
# Out:
# Attack.py		   metrics.py		   TESTING_GUIDE.md
# benchmark_qbad_vs_flad.py  Models_ablation.py	   test_qbad_fl_ablation.py
# checkpoints		   Models.py		   test_qbad_fl.py
# clients.py		   README.md		   VQC_ARCHITECTURE.md
# config.yaml		   requirements_test.txt   vqc_circuit.py
# getData.py		   results
# main.py			   run_full_experiment.py

# %%
# !python3 test_qbad_fl_ablation.py \
    --dataset mnist \
    --rounds 20 \
    --clients 20 \
    --byzantine 5 \
    --attacks 0 1 2 3 4 5 6
# Out:
# Streaming output truncated to the last 5000 lines.
#   [DEBUG] Gradient Norms Analysis:
#     Client  0: norm=7.8879
#     Client  1: norm=7.9002
#     Client  2: norm=7.8762
#     Client  3: norm=7.8860
#     Client  4: norm=7.8845
#     Client  5: norm=7.8913
#     Client  6: norm=7.8787
#     Client  7: norm=7.8794
#     Client  8: norm=7.9137
#     Client  9: norm=7.9086
#     Client 10: norm=7.8840
#     Client 11: norm=7.8854
#     Client 12: norm=7.8766
#     Client 13: norm=7.8850
#     Client 14: norm=7.8911
#     Client 15: norm=503.6417 ← BYZANTINE
#     Client 16: norm=504.9847 ← BYZANTINE
#     Client 17: norm=509.2028 ← BYZANTINE
#     Client 18: norm=505.9712 ← BYZANTINE
#     Client 19: norm=506.7406 ← BYZANTINE
#     Honest norms - Median: 7.8854, Mean: 7.8886, Std: 0.0107
#     Byz norms   - Median: 505.9712, Mean: 506.1082, Std: 1.8623
#   [Gradient Clipping] Clipped 5 updates to max norm 78.8541
# ...

# %%
# !python3 test_qbad_fl_ablation.py \
    --dataset mnist \
    --rounds 20 \
    --clients 20 \
    --byzantine 5 \
    --attacks 0 1 2 3 4 5 6 \
    --iid false
# Out:
# Streaming output truncated to the last 5000 lines.
#     Client  4: norm=6.5780
#     Client  5: norm=6.5516
#     Client  6: norm=6.6104
#     Client  7: norm=6.5444
#     Client  8: norm=6.5606
#     Client  9: norm=6.5311
#     Client 10: norm=6.5460
#     Client 11: norm=6.5505
#     Client 12: norm=6.5281
#     Client 13: norm=6.5216
#     Client 14: norm=6.5658
#     Client 15: norm=505.9227 ← BYZANTINE
#     Client 16: norm=496.1761 ← BYZANTINE
#     Client 17: norm=497.1059 ← BYZANTINE
#     Client 18: norm=496.0135 ← BYZANTINE
#     Client 19: norm=509.7058 ← BYZANTINE
#     Honest norms - Median: 6.5460, Mean: 6.5465, Std: 0.0245
#     Byz norms   - Median: 497.1059, Mean: 500.9848, Std: 5.7153
#   [Gradient Clipping] Clipped 5 updates to max norm 65.4598
#   accuracy=98.28%  detection_rate=100.00%  FPR=0.00%  F1=1.0000  time=72.4s
#   Detected malicious: [15, 16, 17, 18, 19]
#   Actual  malicious : [15, 16, 17, 18, 19]
#
# ─── Round 16/20 ───
# ...
