# %% [markdown]
# <a href="https://colab.research.google.com/github/NehaMyageri04/FLAD/blob/main/IID_%26_NON-IID_10_rounds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clone repo
# !git clone https://github.com/NehaMyageri04/FLAD.git

# !pip install pennylane
print ("main execution for papers , 10 round test, iid and non iid")
# %cd /content/FLAD/6.QBAD-FL
# !git pull origin main

# IID: 10 rounds, all 7 attacks
print("=" * 70)
print("STARTING 10-ROUND IID TESTS (All Attacks)")
print("=" * 70)
# !python test_qbad_fl.py --rounds 10 --attacks 0 1 2 3 4 5 6 2>&1 | tee iid_10rounds.log

print("\n\n" + "=" * 70)
print("STARTING 10-ROUND NON-IID TESTS (All Attacks)")
print("=" * 70)
# !python test_qbad_fl.py --rounds 10 --attacks 0 1 2 3 4 5 6 --iid False 2>&1 | tee non_iid_10rounds.log

print("\n\n✅ BOTH COMPLETE - Logs saved:")
print("  - iid_10rounds.log")
print("  - non_iid_10rounds.log")
# Out:
# Streaming output truncated to the last 5000 lines.
#   [DEBUG] Gradient Norms Analysis:
#     Client  0: norm=7.3209
#     Client  1: norm=7.2851
#     Client  2: norm=7.3084
#     Client  3: norm=7.3301
#     Client  4: norm=7.3042
#     Client  5: norm=7.3105
#     Client  6: norm=7.3210
#     Client  7: norm=7.2989
#     Client  8: norm=7.3333
#     Client  9: norm=7.2973
#     Client 10: norm=7.3035
#     Client 11: norm=7.2887
#     Client 12: norm=7.3069
#     Client 13: norm=7.2835
#     Client 14: norm=7.3059
#     Client 15: norm=42.6328 ← BYZANTINE
#     Client 16: norm=54.9747 ← BYZANTINE
#     Client 17: norm=42.1665 ← BYZANTINE
#     Client 18: norm=72.0364 ← BYZANTINE
#     Client 19: norm=66.4673 ← BYZANTINE
#     Honest norms - Median: 7.3059, Mean: 7.3065, Std: 0.0145
#     Byz norms   - Median: 54.9747, Mean: 55.6555, Std: 12.1428
#   accuracy=98.87%  detection_rate=100.00%  FPR=0.00%  F1=1.0000  time=78.3s
#   Detected malicious: [16, 17, 18, 19, 15]
# ...
